# %%
# %matplotlib inline

import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import bokeh as bk

# %%
imdb_ratings.head()
# Out:
#    Unnamed: 0                     title  year  length  budget  rating  votes  \
# 0           1                         $  1971     121     NaN     6.4    348
# 1           2         $1000 a Touchdown  1939      71     NaN     6.0     20
# 2           3    $21 a Day Once a Month  1941       7     NaN     8.2      5
# 3           4                   $40,000  1996      70     NaN     8.2      6
# 4           5  $50,000 Climax Show, The  1975      71     NaN     3.4     17
#
#      r1    r2   r3  ...      r9   r10  mpaa  Action  Animation  Comedy  Drama  \
# 0   4.5   4.5  4.5  ...     4.5   4.5   NaN       0          0       1      1
# 1   0.0  14.5  4.5  ...     4.5  14.5   NaN       0          0       1      0
# 2   0.0   0.0  0.0  ...    24.5  24.5   NaN       0          1       0      0
# 3  14.5   0.0  0.0  ...    34.5  45.5   NaN       0          0       1      0
# 4  24.5   4.5  0.0  ...     0.0  24.5   NaN       0          0       0      0
#
#   Documentary  Romance  Short
# ...

# %%
imdb_ratings.tail(15)
# Out:
#        Unnamed: 0                    title  year  length      budget  rating  \
# 58773       58774              deadend.com  2002     120         NaN     6.9
# 58774       58775                 e-Dreams  2001      94         NaN     6.8
# 58775       58776                    eMale  2001      17         NaN     7.3
# 58776       58777                eRATicate  2003       9         NaN     6.0
# 58777       58778             eXXXorcismos  2002      78         NaN     4.2
# 58778       58779                 eXistenZ  1999      97         NaN     6.7
# 58779       58780                 f2point8  2002      20         NaN     5.0
# 58780       58781                       f8  2001      13         NaN     7.6
# 58781       58782             pURe kILLjoy  1998      87         NaN     5.2
# 58782       58783                   sIDney  2002      15         NaN     7.0
# 58783       58784                tom thumb  1958      98         NaN     6.5
# ...

# %%
imdb_ratings.describe()
# Out:
#         Unnamed: 0          year        length        budget        rating  \
# count  58788.00000  58788.000000  58788.000000  5.215000e+03  58788.000000
# mean   29394.50000   1976.133582     82.337875  1.341251e+07      5.932850
# std    16970.77815     23.735125     44.347717  2.335008e+07      1.553031
# min        1.00000   1893.000000      1.000000  0.000000e+00      1.000000
# 25%    14697.75000   1958.000000     74.000000  2.500000e+05      5.000000
# 50%    29394.50000   1983.000000     90.000000  3.000000e+06      6.100000
# 75%    44091.25000   1997.000000    100.000000  1.500000e+07      7.000000
# max    58788.00000   2005.000000   5220.000000  2.000000e+08     10.000000
#
#                votes            r1            r2            r3            r4  \
# count   58788.000000  58788.000000  58788.000000  58788.000000  58788.000000
# mean      632.130384      7.014382      4.022377      4.721159      6.374847
# ...

# %%
imdb_ratings.columns
# Out:
# Index(['Unnamed: 0', 'title', 'year', 'length', 'budget', 'rating', 'votes',
#        'r1', 'r2', 'r3', 'r4', 'r5', 'r6', 'r7', 'r8', 'r9', 'r10', 'mpaa',
#        'Action', 'Animation', 'Comedy', 'Drama', 'Documentary', 'Romance',
#        'Short'],
#       dtype='object')

# %%
imdb_ratings.dtypes
# Out:
# Unnamed: 0       int64
# title           object
# year             int64
# length           int64
# budget         float64
# rating         float64
# votes            int64
# r1             float64
# r2             float64
# r3             float64
# r4             float64
# r5             float64
# r6             float64
# r7             float64
# r8             float64
# r9             float64
# r10            float64
# mpaa            object
# Action           int64
# Animation        int64
# Comedy           int64
# Drama            int64
# Documentary      int64
# Romance          int64
# Short            int64
# dtype: object

# %%
imdb_ratings.year.head()
# Out:
# 0    1971
# 1    1939
# 2    1941
# 3    1996
# 4    1975
# Name: year, dtype: int64

# %%
imdb_ratings['year'].value_counts()
# Out:
# 2002    2168
# 2003    2158
# 2001    2121
# 2000    2048
# 2004    1945
# 1999    1927
# 1998    1705
# 1997    1568
# 1996    1390
# 1995    1248
# 1994    1199
# 1993    1016
# 1987     957
# 1992     948
# 1989     944
# 1988     944
# 1990     899
# 1991     888
# 1985     792
# 1986     792
# 1984     749
# 1983     698
# 1982     689
# 1980     681
# 1976     665
# 1981     661
# 1968     651
# 1971     646
# 1972     637
# 1973     634
#         ...
# 1921      53
# 1922      52
# 1919      52
# 1924      50
# 1916      49
# 1923      48
# 1920      43
# 1904      42
# 1918      41
# 1917      37
# 1903      37
# 1912      34
# 1913      32
# 1909      30
# 1901      28
# 1910      26
# 1908      24
# 1911      22
# 1906      17
# 1905      17
# 1900      16
# 1896      13
# 1907      12
# 1894       9
# 1897       9
# 1899       9
# 1902       9
# 1898       5
# 1895       3
# 1893       1
# Name: year, Length: 113, dtype: int64

# %%
imdb_ratings.year.value_counts().sort_index(ascending=False)
# Out:
# 2005     349
# 2004    1945
# 2003    2158
# 2002    2168
# 2001    2121
# 2000    2048
# 1999    1927
# 1998    1705
# 1997    1568
# 1996    1390
# 1995    1248
# 1994    1199
# 1993    1016
# 1992     948
# 1991     888
# 1990     899
# 1989     944
# 1988     944
# 1987     957
# 1986     792
# 1985     792
# 1984     749
# 1983     698
# 1982     689
# 1981     661
# 1980     681
# 1979     632
# 1978     609
# 1977     617
# 1976     665
#         ...
# 1922      52
# 1921      53
# 1920      43
# 1919      52
# 1918      41
# 1917      37
# 1916      49
# 1915      54
# 1914      54
# 1913      32
# 1912      34
# 1911      22
# 1910      26
# 1909      30
# 1908      24
# 1907      12
# 1906      17
# 1905      17
# 1904      42
# 1903      37
# 1902       9
# 1901      28
# 1900      16
# 1899       9
# 1898       5
# 1897       9
# 1896      13
# 1895       3
# 1894       9
# 1893       1
# Name: year, Length: 113, dtype: int64

# %% [markdown]
# # Select the subset of films released after 1999 with an R rating

# %%
imdb_ratings[(imdb_ratings.year > 1999) & (imdb_ratings.mpaa == 'R')].head()
# Out:
#      Unnamed: 0          title  year  length     budget  rating  votes    r1  \
# 6             7        $windle  2002      93        NaN     5.3    200   4.5
# 42           43        'R Xmas  2001      83        NaN     4.9    288  14.5
# 122         123      100 Girls  2000      90        NaN     5.8   3349   4.5
# 123         124  100 Mile Rule  2002      98  1100000.0     5.6    181   4.5
# 152         153          11:11  2004      95        NaN     4.3    222  14.5
#
#        r2   r3  ...     r9   r10  mpaa  Action  Animation  Comedy  Drama  \
# 6     0.0  4.5  ...    4.5  14.5     R       1          0       0      1
# 42    4.5  4.5  ...    4.5   4.5     R       0          0       0      1
# 122   4.5  4.5  ...    4.5   4.5     R       0          0       1      0
# 123   4.5  4.5  ...    4.5  14.5     R       0          0       1      0
# 152  14.5  4.5  ...    4.5  14.5     R       0          0       0      0
#
#     Documentary  Romance  Short
# ...

# %% [markdown]
# # Find the average and variation in ratings for films released in a given year

# %%
imdb_ratings.groupby('year').rating.aggregate([np.mean,np.std])
# Out:
#           mean       std
# year
# 1893  7.000000       NaN
# 1894  4.888889  0.727056
# 1895  5.500000  0.624500
# 1896  5.269231  1.325635
# 1897  4.677778  0.732765
# 1898  5.040000  0.950263
# 1899  4.277778  0.713754
# 1900  4.731250  1.358783
# 1901  4.682143  1.081513
# 1902  4.900000  1.615549
# 1903  4.808108  1.334662
# 1904  4.223810  1.291588
# 1905  5.047059  1.196410
# 1906  5.676471  1.274034
# 1907  5.383333  1.138447
# 1908  4.912500  1.086803
# 1909  5.126667  1.067363
# 1910  5.211538  0.832503
# 1911  5.881818  1.253048
# 1912  6.400000  0.984116
# 1913  6.665625  1.067892
# 1914  6.088889  1.106868
# 1915  6.246296  1.089697
# 1916  6.632653  1.247729
# 1917  6.751351  1.115452
# 1918  6.378049  1.369582
# 1919  7.075000  0.837802
# 1920  6.772093  1.615892
# 1921  6.926415  1.037962
# 1922  6.705769  1.288168
# ...        ...       ...
# 1976  5.586917  1.635209
# 1977  5.732577  1.592237
# 1978  5.598851  1.691051
# 1979  5.545728  1.646573
# ...

# %% [markdown]
# # A single column indicating which genre the film belongs

# %%
imdb_ratings['genre']=imdb_ratings[['Action','Animation','Comedy','Drama','Documentary','Romance']].idxmax(1)

# %%
imdb_ratings['genre'].head(10)
# Out:
# 0         Comedy
# 1         Comedy
# 2      Animation
# 3         Comedy
# 4         Action
# 5          Drama
# 6         Action
# 7    Documentary
# 8          Drama
# 9         Action
# Name: genre, dtype: object

# %% [markdown]
# # Plot the data with colors representing a particular genre. To generate a color code for each genre

# %%
genres_map = {"Action": 'red', "Animation": 'blue', "Comedy": 'yellow', "Drama": 'green', "Documentary": 'orange', "Romance": 'purple'}

# %%
imdb_ratings['genre_color'] = imdb_ratings['genre'].apply(lambda x: genres_map[x])

# %%
imdb_ratings['genre_color'].head()
# Out:
# 0    yellow
# 1    yellow
# 2      blue
# 3    yellow
# 4       red
# Name: genre_color, dtype: object

# %% [markdown]
# # To calculate the average rating per genre per year

# %%
pd.pivot_table(imdb_ratings,values='rating',index='year',columns=['genre'],aggfunc=np.mean)
# Out:
# genre    Action  Animation    Comedy  Documentary     Drama   Romance
# year
# 1893   7.000000        NaN       NaN          NaN       NaN       NaN
# 1894   5.100000        NaN       NaN     4.720000       NaN       NaN
# 1895   5.700000        NaN       NaN     5.400000       NaN       NaN
# 1896   5.875000        NaN  3.900000     5.571429  2.100000       NaN
# 1897   5.900000        NaN  5.200000     4.300000       NaN       NaN
# 1898   6.000000        NaN  5.050000     5.500000  3.600000       NaN
# 1899   4.533333        NaN  3.600000     3.866667  4.850000       NaN
# 1900   5.625000   6.300000  5.250000     3.180000  5.000000       NaN
# 1901   4.375000        NaN  4.937500     4.314286  5.280000       NaN
# 1902   5.725000        NaN  5.600000     3.400000  3.200000       NaN
# 1903   4.600000        NaN  5.437500     4.625000  5.000000  4.600000
# 1904   3.748000        NaN  5.490000     3.800000  4.533333       NaN
# ...

# %%
imdb_ratings.length.plot()

# %%
matplotlib.style.use('ggplot')

# %%
imdb_ratings.length.plot()

# %% [markdown]
# # Density plot of films by their genre

# %%
plot1 = imdb_ratings.groupby('genre').length.plot(kind='kde',xlim=(0,120),legend='genre')
plot1[0].set_xlabel('Number of Minutes')
plot1[0].set_title('Distribution of Films by Runtime Minutes')
# Out:
# Text(0.5,1,'Distribution of Films by Runtime Minutes')

# %% [markdown]
# # Distribution of ratings between genres

# %%
plot2 = imdb_ratings.groupby('genre').rating.plot(kind='kde',xlim=(0,10),legend='genre')
plot2[0].set_xlabel('Ratings')
plot2[0].set_title('Distribution of Ratings')
# Out:
# Text(0.5,1,'Distribution of Ratings')

# %%
pd.pivot_table(imdb_ratings,values='rating',index='title',columns=['genre']).\
plot(kind='box',by='genre').\
set_ylabel('Rating')
# Out:
# Text(0,0.5,'Rating')

# %%
from pandas.tools.plotting import scatter_matrix
scatter_matrix(imdb_ratings[['year','length','budget','rating','votes']], alpha=0.2, figsize=(6, 6), diagonal='kde')
# Out:
# C:\Users\asd\Anaconda2\envs\py36\lib\site-packages\ipykernel\__main__.py:2: FutureWarning: 'pandas.tools.plotting.scatter_matrix' is deprecated, import 'pandas.plotting.scatter_matrix' instead.
#   from ipykernel import kernelapp as app
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000000000AAA90F0>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000D98DA20>]], dtype=object)

# %%
fig, axes = plt.subplots(nrows=3, ncols=2, figsize=(15,15))
row = 0
col = 0
for index, genre in imdb_ratings.groupby('genre'):
    if row > 2:
        row = 0
        col += 1
    genre.groupby('genre').\
    plot(ax=axes[row,col],kind='scatter',x='length',y='rating',s=np.sqrt(genre['votes']),c=genre['genre_color'],xlim=(0,120),ylim=(0,10),alpha=0.5,label=index)
    row += 1
