# %%
data.head(5)
# Out:
#   State  Account Length  Area Code     Phone Int'l Plan VMail Plan  \
# 0    KS             128        415  382-4657         no        yes
# 1    OH             107        415  371-7191         no        yes
# 2    NJ             137        415  358-1921         no         no
# 3    OH              84        408  375-9999        yes         no
# 4    OK              75        415  330-6626        yes         no
#
#    VMail Message  Day Mins  Day Calls  Day Charge   ...    Eve Calls  \
# 0             25     265.1        110       45.07   ...           99
# 1             26     161.6        123       27.47   ...          103
# 2              0     243.4        114       41.38   ...          110
# 3              0     299.4         71       50.90   ...           88
# 4              0     166.7        113       28.34   ...          122
#
#    Eve Charge  Night Mins  Night Calls  Night Charge  Intl Mins  Intl Calls  \
# ...

# %%
account_length = data['Account Length']
account_length.head()
# Out:
# 0    128
# 1    107
# 2    137
# 3     84
# 4     75
# Name: Account Length, dtype: int64

# %%
type(account_length)
# Out:
# pandas.core.series.Series

# %%
subdata = data[['Account Length','VMail Message','Day Calls']]
subdata.head()
# Out:
#    Account Length  VMail Message  Day Calls
# 0             128             25        110
# 1             107             26        123
# 2             137              0        114
# 3              84              0         71
# 4              75              0        113

# %%
wanted = ['Account Length','VMail Message','Day Calls']
column_list = data.columns.values.tolist()
sublist = [x for x in column_list if x not in wanted]
subdata = data[sublist]
subdata.head(5)
# Out:
#   State  Area Code     Phone Int'l Plan VMail Plan  Day Mins  Day Charge  \
# 0    KS        415  382-4657         no        yes     265.1       45.07
# 1    OH        415  371-7191         no        yes     161.6       27.47
# 2    NJ        415  358-1921         no         no     243.4       41.38
# 3    OH        408  375-9999        yes         no     299.4       50.90
# 4    OK        415  330-6626        yes         no     166.7       28.34
#
#    Eve Mins  Eve Calls  Eve Charge  Night Mins  Night Calls  Night Charge  \
# 0     197.4         99       16.78       244.7           91         11.01
# 1     195.5        103       16.62       254.4          103         11.45
# 2     121.2        110       10.30       162.6          104          7.32
# 3      61.9         88        5.26       196.9           89          8.86
# 4     148.3        122       12.61       186.9          121          8.41
#
#    Intl Mins  Intl Calls  Intl Charge  CustServ Calls  Churn?
# ...

# %%
### Filter the rows that have clocked Total Mins to be greater than 500
data1=data[data['Night Mins']>200]
data1.shape
# Out:
# (1687, 21)

# %%
### filter the rows for which the state is VA
data2=data[data['State']=='VA']
data2.shape
# Out:
# (77, 21)

# %%
data3=data[(data['Night Mins']>200) & (data['State']=='VA')]
data3.shape
# Out:
# (48, 21)

# %%
data4=data[(data['Night Mins']>200) | (data['State']=='VA')]
data4.shape
# Out:
# (1716, 21)

# %%
### Selecting the 1st, 2nd and 5th rows from the 2nd, 5th and 7th columns
data.iloc[[1,2,5],[2,5,7]]
# Out:
#    Area Code VMail Plan  Day Mins
# 1        415        yes     161.6
# 2        415         no     243.4
# 5        510         no     223.4

# %%
###  calculate the total minutes spent during the day, evening, and night. This requires summing up the 3 columns, which are Day Mins, Eve Mins, and Night Mins
data['Total Mins'] = data['Day Mins']+data['Eve Mins']+data['Night Mins']

# %%
data['Total Mins'].head(5)
# Out:
# 0    707.2
# 1    611.5
# 2    527.2
# 3    558.2
# 4    501.9
# Name: Total Mins, dtype: float64

# %%
### generating a random integer between 1 and 100
import numpy as np
np.random.randint(1,100)
# Out:
# 51

# %%
### To generate a random number between 0 and 1
np.random.random()
# Out:
# 0.4077542005050133

# %%
### To generate three random numbers between 0 and 100, which are all multiples of 5
import random
for i in range(3):
    print (random.randrange(0,100,5))
# Out:
# 45
# 65
# 85

# %%
### select one column name from the list, at random
column_list=data.columns.values.tolist()
np.random.choice(column_list)
# Out:
# 'Day Mins'

# %%
### generate a set of random numbers that retain their value
np.random.seed(1)
for i in range(5):
    print (np.random.random())
# Out:
# 0.417022004702574
# 0.7203244934421581
# 0.00011437481734488664
# 0.30233257263183977
# 0.14675589081711304

# %% [markdown]
# ## Uniform Distribution

# %%
randnum=np.random.uniform(1,100,100)

# %%
### To check whether it indeed follows the uniform distribution
import matplotlib.pyplot as plt
# %matplotlib inline
a=np.random.uniform(1,100,100000)
b=range(1,101)
plt.hist(a)
# Out:
# (array([ 10137.,   9980.,  10208.,   9849.,   9832.,  10039.,   9989.,
#           9973.,   9926.,  10067.]),
#  array([  1.00102657,  10.90082773,  20.80062889,  30.70043005,
#          40.60023121,  50.50003237,  60.39983352,  70.29963468,
#          80.19943584,  90.099237  ,  99.99903816]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# ## NORMAL DISTRIBUTION

# %%
# %matplotlib inline
a=np.random.randn(100)
b=range(1,101)
plt.plot(b,a)

# %%
# %matplotlib inline
a=np.random.randn(100000)
b=range(1,101)
plt.hist(a)
# Out:
# (array([  1.00000000e+01,   2.13000000e+02,   2.25600000e+03,
#           1.19120000e+04,   2.91510000e+04,   3.34790000e+04,
#           1.80630000e+04,   4.39000000e+03,   4.88000000e+02,
#           3.80000000e+01]),
#  array([-4.6556287 , -3.75609595, -2.85656321, -1.95703046, -1.05749772,
#         -0.15796497,  0.74156777,  1.64110052,  2.54063327,  3.44016601,
#          4.33969876]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# ## Generating a dummy data frame

# %%
d=pd.DataFrame({'A':np.random.randn(10),'B':2.5*np.random.randn(10)+1.5})
d
# Out:
#           A         B
# 0 -0.975607  0.754622
# 1 -0.169107  0.929437
# 2  0.053419  2.556024
# 3  1.697559  4.625941
# 4  0.750090  0.773098
# 5 -0.528176  3.034289
# 6 -1.186659  1.021278
# 7  0.307833  4.578832
# 8  1.183108  0.593743
# 9 -1.970438 -3.705960

# %%
column_list=data.columns.values.tolist()
a=len(column_list)
d=pd.DataFrame({'Column_Name':column_list,'A':np.random.randn(a),'B':2.5*np.random.randn(a)+1.5})
d
# Out:
#            A         B     Column_Name
# 0  -0.112005  1.620114           State
# 1   0.436337  4.220522  Account Length
# 2  -0.530539  3.049056       Area Code
# 3   0.140667  5.426483           Phone
# 4   0.613236  2.691607      Int'l Plan
# 5  -1.215274  4.948979      VMail Plan
# 6  -0.211102  0.758003   VMail Message
# 7   0.613148  2.040082        Day Mins
# 8   1.994119  0.564688       Day Calls
# 9  -1.633000  1.204931      Day Charge
# 10  0.210166  2.312230        Eve Mins
# 11 -0.336956  0.651799       Eve Calls
# 12 -0.752771  1.984880      Eve Charge
# 13 -0.203204  1.018511      Night Mins
# 14  0.431593  3.872384     Night Calls
# 15 -0.073258  0.267896    Night Charge
# 16  0.712484  0.355776       Intl Mins
# 17  0.028981  0.959888      Intl Calls
# 18  0.551886 -0.289253     Intl Charge
# 19  2.190299  3.834231  CustServ Calls
# 20 -0.927824  3.255638          Churn?
# 21  0.267140  9.102635      Total Mins

# %% [markdown]
# # Grouping the data – aggregation, filtering, and transformation

# %%
### create a simple dummy data frame that has a rich mix of both numerical and categorical variables
a=['Male','Female']
b=['Rich','Poor','Middle Class']
gender=[]
seb=[]
for i in range(1,101):
    gender.append(np.random.choice(a))
    seb.append(np.random.choice(b))
height=30*np.random.randn(100)+155
weight=20*np.random.randn(100)+60
age=10*np.random.randn(100)+35
income=1500*np.random.randn(100)+15000

df=pd.DataFrame({'Gender':gender,'Height':height,'Weight':weight,'Age':age,'Income':income,'Socio-Eco':seb})
df.head()
# Out:
#          Age  Gender      Height        Income     Socio-Eco     Weight
# 0  43.277237  Female  156.817602  12949.528478          Rich  31.975170
# 1  40.546843    Male  137.442300  15011.286750          Rich  64.117562
# 2  35.530763  Female  203.415190  14739.705751          Rich  95.407011
# 3  37.081834    Male  166.059616  13911.983777          Rich  60.451845
# 4  19.654289    Male  147.539950  14966.087503  Middle Class  56.586688

# %%
### to group the data frame based on the Gender variable
grouped = df.groupby('Gender')
grouped.groups
# Out:
# {'Female': Int64Index([ 0,  2,  5,  7,  8, 11, 12, 14, 15, 16, 17, 18, 20, 21, 22, 27, 29,
#              30, 31, 33, 34, 37, 38, 41, 44, 47, 49, 50, 51, 54, 57, 58, 59, 61,
#              67, 68, 69, 72, 74, 75, 76, 78, 80, 81, 90, 91, 92, 93, 94, 96, 97,
#              99],
#             dtype='int64'),
#  'Male': Int64Index([ 1,  3,  4,  6,  9, 10, 13, 19, 23, 24, 25, 26, 28, 32, 35, 36, 39,
#              40, 42, 43, 45, 46, 48, 52, 53, 55, 56, 60, 62, 63, 64, 65, 66, 70,
#              71, 73, 77, 79, 82, 83, 84, 85, 86, 87, 88, 89, 95, 98],
#             dtype='int64')}

# %%
grouped=df.groupby('Gender')
for names,groups in grouped:
    print (names)
    print (groups)
# Out:
# Female
#           Age  Gender      Height        Income     Socio-Eco     Weight
# 0   43.277237  Female  156.817602  12949.528478          Rich  31.975170
# 2   35.530763  Female  203.415190  14739.705751          Rich  95.407011
# 5   34.365038  Female  193.718792  16235.987334          Rich  57.085068
# 7   37.638625  Female  186.748211  12837.058504          Poor  59.719452
# 8   47.432668  Female  198.057905  15080.381559  Middle Class  52.758508
# 11  34.332921  Female  140.553990  13105.956232          Rich  51.634145
# 12  38.498014  Female  183.620049  13791.839153          Poor  82.772318
# 14  21.278979  Female  132.122319  12450.297797          Poor  76.430791
# 15  47.011635  Female  163.282080  12025.722041          Rich  43.035009
# 16  43.588530  Female  173.571284  13706.778836  Middle Class  79.471900
# 17  23.802236  Female  143.327540  15357.238402          Poor  53.558862
# 18  37.460860  Female  178.831647  16976.756162  Middle Class  57.895639
# ...

# %%
### A single group can be selected by writing the following:
grouped.get_group('Female')
# Out:
#           Age  Gender      Height        Income     Socio-Eco     Weight
# 0   43.277237  Female  156.817602  12949.528478          Rich  31.975170
# 2   35.530763  Female  203.415190  14739.705751          Rich  95.407011
# 5   34.365038  Female  193.718792  16235.987334          Rich  57.085068
# 7   37.638625  Female  186.748211  12837.058504          Poor  59.719452
# 8   47.432668  Female  198.057905  15080.381559  Middle Class  52.758508
# 11  34.332921  Female  140.553990  13105.956232          Rich  51.634145
# 12  38.498014  Female  183.620049  13791.839153          Poor  82.772318
# 14  21.278979  Female  132.122319  12450.297797          Poor  76.430791
# 15  47.011635  Female  163.282080  12025.722041          Rich  43.035009
# 16  43.588530  Female  173.571284  13706.778836  Middle Class  79.471900
# 17  23.802236  Female  143.327540  15357.238402          Poor  53.558862
# 18  37.460860  Female  178.831647  16976.756162  Middle Class  57.895639
# ...

# %%
grouped=df.groupby(['Gender','Socio-Eco'])
for names,groups in grouped:
    print (names)
    print (groups)
# Out:
# ('Female', 'Middle Class')
#           Age  Gender      Height        Income     Socio-Eco     Weight
# 8   47.432668  Female  198.057905  15080.381559  Middle Class  52.758508
# 16  43.588530  Female  173.571284  13706.778836  Middle Class  79.471900
# 18  37.460860  Female  178.831647  16976.756162  Middle Class  57.895639
# 20  31.970989  Female  159.478176  15158.063341  Middle Class  63.505393
# 27  11.848403  Female  110.119418  16745.767994  Middle Class  77.597207
# 34  16.884814  Female  170.674778  15035.161245  Middle Class  55.502338
# 37  31.801728  Female  153.762465  15419.693918  Middle Class  47.833602
# 38  39.433239  Female  110.043922  13243.245909  Middle Class  89.507560
# 50  34.671171  Female  185.851451  15112.089905  Middle Class  49.226079
# 57  31.705282  Female  116.996522  13977.184744  Middle Class  48.134563
# 74  28.418121  Female  143.918993  15333.610713  Middle Class  32.909525
# ...

# %%
# sum function
grouped=df.groupby(['Gender','Socio-Eco'])
grouped.sum()
# Out:
#                             Age       Height         Income       Weight
# Gender Socio-Eco
# Female Middle Class  539.367266  2221.939654  225119.011422   873.667230
#        Poor          693.746184  3260.960087  297514.619490  1225.630931
#        Rich          628.650705  2861.747626  249053.767895  1038.634986
# Male   Middle Class  594.282644  2688.644185  246734.473111  1036.721415
#        Poor          484.913632  2088.167951  219775.163888   707.421020
#        Rich          577.088113  2603.103542  252243.298307   996.002677

# %%
### To get the number of rows in each group (or calculate the size of each group)
grouped=df.groupby(['Gender','Socio-Eco'])
grouped.size()
# Out:
# Gender  Socio-Eco
# Female  Middle Class    15
#         Poor            20
#         Rich            17
# Male    Middle Class    17
#         Poor            14
#         Rich            17
# dtype: int64

# %%
### to get the summary statistics for each group separately
grouped=df.groupby(['Gender','Socio-Eco'])
grouped.describe()
# Out:
#                       Age                                              \
#                     count       mean        std        min        25%
# Gender Socio-Eco
# Female Middle Class  15.0  35.957818  12.319602  11.848403  30.061702
#        Poor          20.0  34.687309  10.231798  19.864277  26.590298
#        Rich          17.0  36.979453   7.581594  22.153261  34.295338
# Male   Middle Class  17.0  34.957803   9.765213  18.320490  26.057097
#        Poor          14.0  34.636688  11.839032  16.339715  27.126020
#        Rich          17.0  33.946360   9.141802  12.062484  30.637271
#
#                                                      Height              \
#                            50%        75%        max  count        mean
# Gender Socio-Eco
# Female Middle Class  34.671171  45.510599  52.572506   15.0  148.129310
#        Poor          34.931219  40.945858  57.902933   20.0  163.048004
#        Rich          36.855328  43.277237  47.071869   17.0  168.338096
# ...

# %%
### calculate sum of Income, mean of Age, and standard deviation of Height
grouped=df.groupby(['Gender','Socio-Eco'])
grouped.aggregate({'Income':np.sum,'Age':np.mean,'Height':np.std})
# Out:
#                             Income        Age     Height
# Gender Socio-Eco
# Female Middle Class  225119.011422  35.957818  30.773219
#        Poor          297514.619490  34.687309  26.145465
#        Rich          249053.767895  36.979453  27.560901
# Male   Middle Class  246734.473111  34.957803  19.929316
#        Poor          219775.163888  34.636688  28.510715
#        Rich          252243.298307  33.946360  30.455948

# %%
grouped=df.groupby(['Gender','Socio-Eco'])
grouped.aggregate({'Age':np.mean,'Height':lambda
                   x:np.mean(x)/np.std(x)})
# Out:
#                            Age    Height
# Gender Socio-Eco
# Female Middle Class  35.957818  4.982527
#        Poor          34.687309  6.398193
#        Rich          36.979453  6.295837
# Male   Middle Class  34.957803  8.180060
#        Poor          34.636688  5.429022
#        Rich          33.946360  5.182447

# %%
### apply several functions to all the columns at the same time
grouped.aggregate([np.sum, np.mean, np.std])
# Out:
#                             Age                             Height  \
#                             sum       mean        std          sum
# Gender Socio-Eco
# Female Middle Class  539.367266  35.957818  12.319602  2221.939654
#        Poor          693.746184  34.687309  10.231798  3260.960087
#        Rich          628.650705  36.979453   7.581594  2861.747626
# Male   Middle Class  594.282644  34.957803   9.765213  2688.644185
#        Poor          484.913632  34.636688  11.839032  2088.167951
#        Rich          577.088113  33.946360   9.141802  2603.103542
#
#                                                    Income                \
#                            mean        std            sum          mean
# Gender Socio-Eco
# Female Middle Class  148.129310  30.773219  225119.011422  15007.934095
#        Poor          163.048004  26.145465  297514.619490  14875.730974
#        Rich          168.338096  27.560901  249053.767895  14650.221641
# ...

# %%
### choose elements from the Age column that are a part of the group wherein the sum of Age is greater than 700
groupage = grouped['Age'].filter(lambda x:x.sum()>700)
groupage.head()
# Out:
# Series([], Name: Age, dtype: float64)

# %% [markdown]
# # Transformation

# %%
zscore = lambda x: (x - x.mean()) / x.std()
grouped.transform(zscore).head(5)
# Out:
#         Age    Height    Income    Weight
# 0  0.830668 -0.418001 -1.317061 -1.678375
# 1  0.722011 -0.514889  0.129949  0.402200
# 2 -0.191080  1.272712  0.069299  1.977488
# 3  0.342982  0.424741 -0.693670  0.135550
# 4 -1.567146 -0.532662  0.472643 -0.252972

# %%
### to calculate the standard normal values for all the elements in the numerical columns of our data frame
### It is the same we do in sklearn for firt and transform used for feature scaling
zscore = lambda x: (x - x.mean()) / x.std()
grouped.transform(zscore)
# Out:
#          Age    Height    Income    Weight
# 0   0.830668 -0.418001 -1.317061 -1.678375
# 1   0.722011 -0.514889  0.129949  0.402200
# 2  -0.191080  1.272712  0.069299  1.977488
# 3   0.342982  0.424741 -0.693670  0.135550
# 4  -1.567146 -0.532662  0.472643 -0.252972
# 5  -0.344837  0.920895  1.228059 -0.231178
# 6   0.651984  0.335655  0.582635 -1.113479
# 7   0.288445  0.906475 -1.239845 -0.091453
# 8   0.931430  1.622469  0.064135 -0.304100
# 9   1.952285  0.117461  0.154715  1.520389
# 10 -0.134016 -0.201752 -0.004493  0.434144
# 11 -0.349073 -1.008099 -1.195920 -0.545339
# 12  0.372437  0.786830 -0.659183  1.258184
# 13 -0.653487 -0.265164 -0.454568  1.066362
# 14 -1.310457 -1.182832 -1.475059  0.886917
# 15  1.323229 -0.183449 -2.032481 -1.040946
# 16  0.619396  0.826757 -1.151862  1.176685
# 17 -1.063848 -0.754259  0.292835 -0.452127
# 18  0.122004  0.997697  1.742921 -0.019337
# 19  1.293737 -2.198044  0.609573  1.450843
# 20 -0.323617  0.368790  0.132904  0.291625
# ...

# %%
### to fill the missing values with the mean of the non-missing values
f = lambda x: x.fillna(x.mean())
grouped.transform(f)
# Out:
#           Age      Height        Income     Weight
# 0   43.277237  156.817602  12949.528478  31.975170
# 1   40.546843  137.442300  15011.286750  64.117562
# 2   35.530763  203.415190  14739.705751  95.407011
# 3   37.081834  166.059616  13911.983777  60.451845
# 4   19.654289  147.539950  14966.087503  56.586688
# 5   34.365038  193.718792  16235.987334  57.085068
# 6   39.906671  163.346418  15615.497354  43.281039
# 7   37.638625  186.748211  12837.058504  59.719452
# 8   47.432668  198.057905  15080.381559  52.758508
# 9   51.793767  156.701116  15044.342307  79.489672
# 10  33.649111  154.134770  14509.492753  68.529503
# 11  34.332921  140.553990  13105.956232  51.634145
# 12  38.498014  183.620049  13791.839153  82.772318
# 13  26.900029  141.594826  14957.735357  74.409487
# 14  21.278979  132.122319  12450.297797  76.430791
# 15  47.011635  163.282080  12025.722041  43.035009
# 16  43.588530  173.571284  13706.778836  79.471900
# ...

# %%
### first row of each group
grouped.head(1)
# Out:
#           Age  Gender      Height        Income     Socio-Eco     Weight
# 0   43.277237  Female  156.817602  12949.528478          Rich  31.975170
# 1   40.546843    Male  137.442300  15011.286750          Rich  64.117562
# 4   19.654289    Male  147.539950  14966.087503  Middle Class  56.586688
# 7   37.638625  Female  186.748211  12837.058504          Poor  59.719452
# 8   47.432668  Female  198.057905  15080.381559  Middle Class  52.758508
# 13  26.900029    Male  141.594826  14957.735357          Poor  74.409487

# %%
### the last row of each group
grouped.tail(1)
# Out:
#           Age  Gender      Height        Income     Socio-Eco     Weight
# 83  26.057097    Male  177.349002  13929.349812  Middle Class  64.290568
# 94  27.481757  Female  152.383634  14665.054995  Middle Class  67.807908
# 95  32.849866    Male  123.570032  17219.495788          Poor  69.307347
# 97  28.298422  Female  173.643650  14473.819057          Rich  73.700081
# 98  34.344132    Male  197.186807  14549.550668          Rich  80.700529
# 99  26.693301  Female  195.152823  18531.417138          Poor  68.676641

# %%
### to look at the youngest male and female members
df1=df.sort_values(['Age','Income'])
grouped=df1.groupby('Gender')
grouped.head(1)
# Out:
#           Age  Gender      Height        Income     Socio-Eco     Weight
# 27  11.848403  Female  110.119418  16745.767994  Middle Class  77.597207
# 25  12.062484    Male  185.282898  14041.272208          Rich  50.419164

# %% [markdown]
# # Concatenating and appending data

# %%
data1=pd.read_csv("E:/O'Reilly - Advance predictive analytics/Chapter 3/winequality-red.csv",sep=';')
data1.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
data1.columns.values
# Out:
# array(['fixed acidity', 'volatile acidity', 'citric acid',
#        'residual sugar', 'chlorides', 'free sulfur dioxide',
#        'total sulfur dioxide', 'density', 'pH', 'sulphates', 'alcohol',
#        'quality'], dtype=object)

# %%
data1.shape
# Out:
# (1599, 12)

# %%
data2=pd.read_csv("E:/O'Reilly - Advance predictive analytics/Chapter 3/winequality-white.csv",sep=';')
data2.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# ...

# %%
data2.columns.values
# Out:
# array(['fixed acidity', 'volatile acidity', 'citric acid',
#        'residual sugar', 'chlorides', 'free sulfur dioxide',
#        'total sulfur dioxide', 'density', 'pH', 'sulphates', 'alcohol',
#        'quality'], dtype=object)

# %%
data2.shape
# Out:
# (4898, 12)

# %%
wine_total = pd.concat([data1,data2], axis =0)

# %%
wine_total.shape
# Out:
# (6497, 12)

# %%
data1_wine = data1.head(50)
data2_wine = data1[500:550]
data3_wine = data1.tail(50)
wine_scramble = pd.concat([data1_wine, data2_wine, data3_wine], axis = 0)
wine_scramble
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# 5               7.4             0.660         0.00             1.8      0.075
# 6               7.9             0.600         0.06             1.6      0.069
# 7               7.3             0.650         0.00             1.2      0.065
# 8               7.8             0.580         0.02             2.0      0.073
# 9               7.5             0.500         0.36             6.1      0.071
# 10              6.7             0.580         0.08             1.8      0.097
# ...

# %%
## Concatenating 332 csv files

# %%
data=pd.read_csv("E:/O'Reilly - Advance predictive analytics/Chapter 3/lotofdata/001.csv",sep=';')
data.head()
# Out:
#   Date,"sulfate","nitrate","ID"
# 0            2003-01-01,NA,NA,1
# 1            2003-01-02,NA,NA,1
# 2            2003-01-03,NA,NA,1
# 3            2003-01-04,NA,NA,1
# 4            2003-01-05,NA,NA,1

# %%
filepath="E:/O'Reilly - Advance predictive analytics/Chapter 3/lotofdata"
data_final=pd.read_csv("E:/O'Reilly - Advance predictive analytics/Chapter 3/lotofdata/001.csv")
for i in range(1,333):
    if i<10:
        filename='0'+'0'+str(i)+'.csv'
    if 10<=i<100:
        filename='0'+str(i)+'.csv'
    if i>=100:
        filename=str(i)+'.csv'
        
    file=filepath+'/'+filename
    data=pd.read_csv(file)
    
    data_final=pd.concat([data_final,data],axis=0)

# %%
data_final.shape
# Out:
# (773548, 4)

# %%
filepath="E:/O'Reilly - Advance predictive analytics/Chapter 3/lotofdata"
data_final=pd.read_csv("E:/O'Reilly - Advance predictive analytics/Chapter 3/lotofdata/001.csv")
data_final_size=len(data_final)
for i in range(1,333):
    if i<10:
        filename='0'+'0'+str(i)+'.csv'
    if 10<=i<100:
        filename='0'+str(i)+'.csv'
    if i>=100:
        filename=str(i)+'.csv'
        
    file=filepath+'/'+filename
    data=pd.read_csv(file)
    data_final_size+=len(data)
    data_final=pd.concat([data_final,data],axis=0)
print (data_final_size)
# Out:
# 773548
